# %% [markdown]
# #**TITANIC DATASET**

# %% [markdown]
# ![texto alternativo](https://faithmag.com/sites/default/files/styles/original/public/2018-09/titanic2.jpg?itok=apbN46lv)

# %% [markdown]
# Source: https://faithmag.com/

# %% [markdown]
# ##**Setup**

# %% [markdown]
# ###**EXERCISE 1**: *

# %% [markdown]
# Import matplotlib, numpy, pandas and seaborn and set your favourite seaborn style:

# %%
#CODE HERE

# %% [markdown]
# ###**EXERCISE 2**: *

# %% [markdown]
# Import the titanic data set at https://raw.githubusercontent.com/immune-institute/viz-datasets/main/titanic.csv

# %%
#CODE HERE

# %% [markdown]
# ##**Distribution plots**

# %% [markdown]
# Recreate the plots below

# %% [markdown]
# ###**EXERCISE 3**: *

# %% [markdown]
# What does fare ticket fare distribution look like?

# %%
#CODE HERE

# %% [markdown]
# Is there actually any ticket between 300 and 450?

# %%
#CODE HERE

# %% [markdown]
# ###**EXERCISE 4**: *

# %% [markdown]
# Is there any pattern for ticket fare vs. passenger age?

# %%
#CODE HERE

# %% [markdown]
# There are many overlapping points, what can we do to get a better understanding?

# %%
#CODE HERE

# %% [markdown]
# ###**EXERCISE 5**: **

# %% [markdown]
# We would like to check the influence of sex as a third dimension. How can we build a jointplot for that matter?

# %%
#CODE HERE

# %% [markdown]
# ##**Categorical plots**

# %% [markdown]
# ###**EXERCISE 6**: **

# %% [markdown]
# How many passengers did belong to each class?

# %%
#CODE HERE

# %% [markdown]
# How many passengers did belong to each class **per sex**?

# %%
#CODE HERE

# %% [markdown]
# ###**EXERCISE 7**: *

# %% [markdown]
# What is de average age of passengers per sex?

# %%
#CODE HERE

# %% [markdown]
# Does origin city influence on these results?

# %%
#CODE HERE

# %% [markdown]
# ###**EXERCISE 8**: *

# %% [markdown]
# Compare the distribution of age per class with a box plot

# %%
#CODE HERE

# %% [markdown]
# Include survived dimension as a hue:

# %%
#CODE HERE

# %% [markdown]
# ###**EXERCISE 9**: *

# %% [markdown]
# Repeat previous exercise now using violing plots:

# %%
#CODE HERE

# %%
#CODE HERE

# %% [markdown]
# ###**EXERCISE 10**: **

# %% [markdown]
# Compare the distribution of fare per person type (adult>=16):

# %%
#CODE HERE

# %%
#CODE HERE

# %% [markdown]
# ##**Grid Plots**

# %% [markdown]
# ###**EXERCISE 11**: **

# %% [markdown]
# Develop the plot shown below:

# %%
#CODE HERE

# %% [markdown]
# ###**EXERCISE 12**: *

# %% [markdown]
# Show dataset variable correlation:

# %%
#CODE HERE

# %% [markdown]
# ##**Extra Plots**

# %% [markdown]
# ###**EXERCISE 13**: ****

# %% [markdown]
# Let's look at how people's title affects survival rate:

# %%
#CODE HERE

# %%
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
#CODE HERE

# %%
#CODE HERE
